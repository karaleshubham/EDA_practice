# %% [markdown]
# **Import required packages**

# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# **Read the data**

# %%
visa_df=pd.read_csv(r"C:\Users\User\Desktop\Naresh IT\datafiles\visadataset.csv")

visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %% [markdown]
# $head$
#
# - top 5 rows

# %%
visa_df.head()

#default it will come up with 5 heads
# Out:
#   case_id continent education_of_employee has_job_experience  \
# 0  EZYV01      Asia           High School                  N
# 1  EZYV02      Asia              Master's                  Y
# 2  EZYV03      Asia            Bachelor's                  N
# 3  EZYV04      Asia            Bachelor's                  N
# 4  EZYV05    Africa              Master's                  Y
#
#   requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 0                     N            14513         2007                 West
# 1                     N             2412         2002            Northeast
# 2                     Y            44444         2008                 West
# 3                     N               98         1897                 West
# 4                     N             1082         2005                South
#
#    prevailing_wage unit_of_wage full_time_position case_status
# 0         592.2029         Hour                  Y      Denied
# ...

# %% [markdown]
# $tail$
#
# - last 5 rows

# %%
visa_df.tail()
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 25475                     Y             2601         2008
# 25476                     N             3274         2006
# 25477                     N             1121         1910
# 25478                     Y             1918         1887
# 25479                     N             3195         1960
#
#       region_of_employment  prevailing_wage unit_of_wage full_time_position  \
# 25475                South         77092.57         Year                  Y
# ...

# %% [markdown]
# $shape$
#
# - number of rows and number of columns

# %%
visa_df.shape
# Out:
# (25480, 12)

# %%
print(f"the number of rows are {visa_df.shape[0]}")
print(f"the number of rows are {visa_df.shape[1]}")
# Out:
# the number of rows are 25480
# the number of rows are 12

# %% [markdown]
# $size$
#
# - number of rows*number of columns

# %%
visa_df.size
# Out:
# 305760

# %% [markdown]
# $columns$

# %%
visa_df.columns
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'no_of_employees', 'yr_of_estab',
#        'region_of_employment', 'prevailing_wage', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')

# %% [markdown]
# $dtypes$

# %%
visa_df.dtypes

#object means categorical
#int n float means numerical
# Out:
# case_id                   object
# continent                 object
# education_of_employee     object
# has_job_experience        object
# requires_job_training     object
# no_of_employees            int64
# yr_of_estab                int64
# region_of_employment      object
# prevailing_wage          float64
# unit_of_wage              object
# full_time_position        object
# case_status               object
# dtype: object

# %% [markdown]
# - understanding data types are very important
#
# - visa_df type is: **DataFrame**
#
# - visa_df.values is:**series**
#
# - Series objects can convert into dictionary
#
# - after that you can use dictionary methods

# %%
type(visa_df)
# Out:
# pandas.core.frame.DataFrame

# %%
type(visa_df.dtypes)
# Out:
# pandas.core.series.Series

# %% [markdown]
# ***Task***
#
# - Create categorical list
#
# - Create numerical column list
#
# **idea**
#
# - convert series type into dictionary
#
# - iterate through loop
#
# - apply the condition get the result in the list

# %%
dict(visa_df.dtypes)
# Out:
# {'case_id': dtype('O'),
#  'continent': dtype('O'),
#  'education_of_employee': dtype('O'),
#  'has_job_experience': dtype('O'),
#  'requires_job_training': dtype('O'),
#  'no_of_employees': dtype('int64'),
#  'yr_of_estab': dtype('int64'),
#  'region_of_employment': dtype('O'),
#  'prevailing_wage': dtype('float64'),
#  'unit_of_wage': dtype('O'),
#  'full_time_position': dtype('O'),
#  'case_status': dtype('O')}

# %%
dict2=dict(visa_df.dtypes)

for i in dict2:
    
    if dict2[i]==object:
        print("categorical")
    elif dict2[i]==int or dict2[i]==float:
        print("numerical")
    
    else:
        print("nothing")
# Out:
# categorical
# categorical
# categorical
# categorical
# categorical
# nothing
# nothing
# categorical
# numerical
# categorical
# categorical
# categorical

# %%
for key,value in dict2.items():
    if value=="object":
        print(f"{key}:{value}")
    
    else:
        print(f"{key}:{value}")
# Out:
# case_id:object
# continent:object
# education_of_employee:object
# has_job_experience:object
# requires_job_training:object
# no_of_employees:int64
# yr_of_estab:int64
# region_of_employment:object
# prevailing_wage:float64
# unit_of_wage:object
# full_time_position:object
# case_status:object

# %% [markdown]
# $Select-data-types$
#
# - select data types can give a datframe of desired data types
#
# - now the result also a dataframe
#
# - all above options like head, tail, columns

# %%
visa_df.select_dtypes(include='object')
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training region_of_employment unit_of_wage  \
# 0                         N                 West         Hour
# ...

# %%
visa_df.select_dtypes(exclude='object')
# Out:
#        no_of_employees  yr_of_estab  prevailing_wage
# 0                14513         2007         592.2029
# 1                 2412         2002       83425.6500
# 2                44444         2008      122996.8600
# 3                   98         1897       83434.0300
# 4                 1082         2005      149907.3900
# ...                ...          ...              ...
# 25475             2601         2008       77092.5700
# 25476             3274         2006      279174.7900
# 25477             1121         1910      146298.8500
# 25478             1918         1887       86154.7700
# 25479             3195         1960       70876.9100
#
# [25480 rows x 3 columns]

# %%
visa_df.select_dtypes(include='object').tail
# Out:
# <bound method NDFrame.tail of          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training region_of_employment unit_of_wage  \
# ...

# %% [markdown]
# $is$-$null$
#
# - is null used to identify the any missing values are available
#
# - is null means we are asking  question to the computer
#
# - it will give  True or False
#
# - True: yes value is missed
#
# - False: no values is not missed

# %% [markdown]
# **note**
#
# - if we see bound method means add the brackets

# %%
visa_df.isnull()
# Out:
#        case_id  continent  education_of_employee  has_job_experience  \
# 0        False      False                  False               False
# 1        False      False                  False               False
# 2        False      False                  False               False
# 3        False      False                  False               False
# 4        False      False                  False               False
# ...        ...        ...                    ...                 ...
# 25475    False      False                  False               False
# 25476    False      False                  False               False
# 25477    False      False                  False               False
# 25478    False      False                  False               False
# 25479    False      False                  False               False
#
#        requires_job_training  no_of_employees  yr_of_estab  \
# 0                      False            False        False
# ...

# %%
visa_df.isna()
# Out:
#        case_id  continent  education_of_employee  has_job_experience  \
# 0        False      False                  False               False
# 1        False      False                  False               False
# 2        False      False                  False               False
# 3        False      False                  False               False
# 4        False      False                  False               False
# ...        ...        ...                    ...                 ...
# 25475    False      False                  False               False
# 25476    False      False                  False               False
# 25477    False      False                  False               False
# 25478    False      False                  False               False
# 25479    False      False                  False               False
#
#        requires_job_training  no_of_employees  yr_of_estab  \
# 0                      False            False        False
# ...

# %%
visa_df.isnull().sum()
# Out:
# case_id                  0
# continent                0
# education_of_employee    0
# has_job_experience       0
# requires_job_training    0
# no_of_employees          0
# yr_of_estab              0
# region_of_employment     0
# prevailing_wage          0
# unit_of_wage             0
# full_time_position       0
# case_status              0
# dtype: int64

# %% [markdown]
# $drop$-$duplicates$
#
# - if any duplicate rows are there then we can drop it

# %%
visa_df.drop_duplicates()
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
visa_df.drop_duplicates().all()
# Out:
# case_id                  True
# continent                True
# education_of_employee    True
# has_job_experience       True
# requires_job_training    True
# no_of_employees          True
# yr_of_estab              True
# region_of_employment     True
# prevailing_wage          True
# unit_of_wage             True
# full_time_position       True
# case_status              True
# dtype: bool

# %%
visa_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25480 entries, 0 to 25479
# Data columns (total 12 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   case_id                25480 non-null  object
#  1   continent              25480 non-null  object
#  2   education_of_employee  25480 non-null  object
#  3   has_job_experience     25480 non-null  object
#  4   requires_job_training  25480 non-null  object
#  5   no_of_employees        25480 non-null  int64
#  6   yr_of_estab            25480 non-null  int64
#  7   region_of_employment   25480 non-null  object
#  8   prevailing_wage        25480 non-null  float64
#  9   unit_of_wage           25480 non-null  object
#  10  full_time_position     25480 non-null  object
#  11  case_status            25480 non-null  object
# dtypes: float64(1), int64(2), object(9)
# memory usage: 2.3+ MB

# %%
visa_df.describe()
# Out:
#        no_of_employees   yr_of_estab  prevailing_wage
# count     25480.000000  25480.000000     25480.000000
# mean       5667.043210   1979.409929     74455.814592
# std       22877.928848     42.366929     52815.942327
# min         -26.000000   1800.000000         2.136700
# 25%        1022.000000   1976.000000     34015.480000
# 50%        2109.000000   1997.000000     70308.210000
# 75%        3504.000000   2005.000000    107735.512500
# max      602069.000000   2016.000000    319210.270000

# %% [markdown]
# $Take$
#
# - take is used to extract the perticular index of data
#
# - take has one parameter called axis
#
# - axis=1 means columns
#
# - axis=0 means rows
#
# - by default axis=0 is there
#
# - in below example we given 100,200,300 and we did not provide axis values
#
# - it understood we are talking about rows
#
# -  in take we cant get the rows n colums at a time #drawback

# %%
visa_df.take([100,200,300])
# Out:
#      case_id continent education_of_employee has_job_experience  \
# 100  EZYV101      Asia              Master's                  Y
# 200  EZYV201      Asia             Doctorate                  Y
# 300  EZYV301      Asia              Master's                  Y
#
#     requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 100                     N             2227         2007            Northeast
# 200                     N             3282         1979                 West
# 300                     N             3268         2012              Midwest
#
#      prevailing_wage unit_of_wage full_time_position case_status
# 100         28243.79         Year                  Y   Certified
# 200         74441.11         Year                  Y   Certified
# 300        101371.21         Year                  Y   Certified

# %%
visa_df.take([11],axis=1)# only 12 rows are there so we cant use more than that or else it will give error
# Out:
#       case_status
# 0          Denied
# 1       Certified
# 2          Denied
# 3          Denied
# 4       Certified
# ...           ...
# 25475   Certified
# 25476   Certified
# 25477   Certified
# 25478   Certified
# 25479   Certified
#
# [25480 rows x 1 columns]

# %%
visa_df.take([i for i in range (200)]) #instead of that we can use slicing df[1:200]
# Out:
#      case_id continent education_of_employee has_job_experience  \
# 0     EZYV01      Asia           High School                  N
# 1     EZYV02      Asia              Master's                  Y
# 2     EZYV03      Asia            Bachelor's                  N
# 3     EZYV04      Asia            Bachelor's                  N
# 4     EZYV05    Africa              Master's                  Y
# ..       ...       ...                   ...                ...
# 195  EZYV196      Asia            Bachelor's                  N
# 196  EZYV197    Europe              Master's                  N
# 197  EZYV198    Europe              Master's                  N
# 198  EZYV199      Asia              Master's                  N
# 199  EZYV200    Europe              Master's                  Y
#
#     requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 0                       N            14513         2007                 West
# ...

# %% [markdown]
# $iloc$

# %%
#visa_df.iloc[<rows><columns>]
#visa_df.iloc()

# %%
visa_df.iloc[[100,200,300],[1,4,7]]
# Out:
#     continent requires_job_training region_of_employment
# 100      Asia                     N            Northeast
# 200      Asia                     N                 West
# 300      Asia                     N              Midwest

# %%
visa_df.iloc[100:105,1:5]
# Out:
#     continent education_of_employee has_job_experience requires_job_training
# 100      Asia              Master's                  Y                     N
# 101      Asia              Master's                  Y                     N
# 102      Asia            Bachelor's                  Y                     N
# 103      Asia             Doctorate                  Y                     N
# 104      Asia              Master's                  Y                     N

# %%
visa_df.iloc[[100,200,300]] #same likw take it will coime
# Out:
#      case_id continent education_of_employee has_job_experience  \
# 100  EZYV101      Asia              Master's                  Y
# 200  EZYV201      Asia             Doctorate                  Y
# 300  EZYV301      Asia              Master's                  Y
#
#     requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 100                     N             2227         2007            Northeast
# 200                     N             3282         1979                 West
# 300                     N             3268         2012              Midwest
#
#      prevailing_wage unit_of_wage full_time_position case_status
# 100         28243.79         Year                  Y   Certified
# 200         74441.11         Year                  Y   Certified
# 300        101371.21         Year                  Y   Certified

# %%
visa_df.iloc[100,]
# Out:
# case_id                    EZYV101
# continent                     Asia
# education_of_employee     Master's
# has_job_experience               Y
# requires_job_training            N
# no_of_employees               2227
# yr_of_estab                   2007
# region_of_employment     Northeast
# prevailing_wage           28243.79
# unit_of_wage                  Year
# full_time_position               Y
# case_status              Certified
# Name: 100, dtype: object

# %%
visa_df.iloc[100,0:]
# Out:
# case_id                    EZYV101
# continent                     Asia
# education_of_employee     Master's
# has_job_experience               Y
# requires_job_training            N
# no_of_employees               2227
# yr_of_estab                   2007
# region_of_employment     Northeast
# prevailing_wage           28243.79
# unit_of_wage                  Year
# full_time_position               Y
# case_status              Certified
# Name: 100, dtype: object

# %% [markdown]
# **note**
#
# - no bracket then series
#
# - with square bracket is dataframe

# %%
visa_df.iloc[:,[5]]
# Out:
#        no_of_employees
# 0                14513
# 1                 2412
# 2                44444
# 3                   98
# 4                 1082
# ...                ...
# 25475             2601
# 25476             3274
# 25477             1121
# 25478             1918
# 25479             3195
#
# [25480 rows x 1 columns]

# %%
#when we have to know thw specific index column then we have to use the index function 
#but the index will work only for list 
# first we have to convert that to list then index it 



cols=list(visa_df.columns)

# %%
type(cols)
# Out:
# list

# %%
cols.index('no_of_employees')
# Out:
# 5

# %% [markdown]
# $loc$
#
# - loc will take directly columns names

# %%
visa_df.loc[[100,200,300],['no_of_employees']]
# Out:
#      no_of_employees
# 100             2227
# 200             3282
# 300             3268

# %%
visa_df.loc[[100,200,300],'no_of_employees':]
# Out:
#      no_of_employees  yr_of_estab region_of_employment  prevailing_wage  \
# 100             2227         2007            Northeast         28243.79
# 200             3282         1979                 West         74441.11
# 300             3268         2012              Midwest        101371.21
#
#     unit_of_wage full_time_position case_status
# 100         Year                  Y   Certified
# 200         Year                  Y   Certified
# 300         Year                  Y   Certified

# %%
visa_df.loc[[100,300],['no_of_employees']]
# Out:
#      no_of_employees
# 100             2227
# 300             3268
